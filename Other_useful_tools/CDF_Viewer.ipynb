# %% [markdown]
# ### Quick preview of CDF format files

# %%
import netCDF4 as nc
import numpy as np

dr1 = 'C:/Users/woshi/Desktop/CE_675_Project/Data/emis_data/emis_mole_all_20160101_4NC3_withbeis_2016fg_16j.ncf'
dr2 = 'C:/Users/woshi/Desktop/CE_675_Project/Data/emis_data/emis_mole_all_20160102_4NC3_withbeis_2016fg_16j.ncf'
emis = nc.Dataset(dr1)
# emis2 = nc.Dataset(dr2)
emis
# print (emis.variables['NO'][24,0,0,0])
# print (emis2.variables['NO'][0,0,0,0])
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_64BIT_OFFSET data model, file format NETCDF3):
#     IOAPI_VERSION: ioapi-3.2: $Id: init3.F90 98 2018-04-05 14:35:07Z coats $
#     EXEC_ID: ????????????????
#     FTYPE: 1
#     CDATE: 2019192
#     CTIME: 200045
#     WDATE: 2019192
#     WTIME: 200045
#     SDATE: 2016001
#     STIME: 0
#     TSTEP: 10000
#     NTHIK: 1
#     NCOLS: 237
#     NROWS: 153
#     NLAYS: 1
#     NVARS: 67
#     GDTYP: 2
#     P_ALP: 33.0
#     P_BET: 45.0
#     P_GAM: -97.0
#     XCENT: -97.0
#     YCENT: 40.0
#     XORIG: 960000.0
#     YORIG: -660000.0
#     XCELL: 4000.0
#     YCELL: 4000.0
#     VGTYP: -1
#     VGTOP: 0.0
#     VGLVLS: [0. 0.]
#     GDNAM: 4NC3
#     UPNAM: MRGGRID
# ...

# %%
dr2 = 'C:/Users/woshi/Desktop/CE_675_Project/Data/met_data/metcro2d.4nc3.35l.160101'
met = nc.Dataset(dr2)
print (met)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format NETCDF3):
#     IOAPI_VERSION: ioapi-3.2: $Id: init3.F90 1 2017-06-10 18:05:20Z coats $
#     EXEC_ID: mcip
#     FTYPE: 1
#     CDATE: 2019176
#     CTIME: 203249
#     WDATE: 2019176
#     WTIME: 203249
#     SDATE: 2016001
#     STIME: 0
#     TSTEP: 10000
#     NTHIK: 1
#     NCOLS: 237
#     NROWS: 153
#     NLAYS: 1
#     NVARS: 41
#     GDTYP: 2
#     P_ALP: 33.0
#     P_BET: 45.0
#     P_GAM: -97.0
#     XCENT: -97.0
#     YCENT: 40.0
#     XORIG: 960000.0
#     YORIG: -660000.0
#     XCELL: 4000.0
#     YCELL: 4000.0
#     VGTYP: 7
#     VGTOP: 5000.0
#     VGLVLS: [1.     0.9975]
#     GDNAM: 4NC3_CROSS
#     UPNAM: OUTCM3IO
# ...

# %%
dr3 = 'C:/Users/woshi/Desktop/CE_675_Project/Data/aq_conc/CCTM_ACONC_v521_intel2018.2.199_4km_NC_20160101.nc'
aq_conc = nc.Dataset(dr3)
print (aq_conc)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_64BIT_OFFSET data model, file format NETCDF3):
#     IOAPI_VERSION: ioapi-3.2: $Id: init3.F90 98 2018-04-05 14:35:07Z coats $
#     EXEC_ID: CCTM_v521.exe
#     FTYPE: 1
#     CDATE: 2019249
#     CTIME: 32604
#     WDATE: 2019249
#     WTIME: 32604
#     SDATE: 2016001
#     STIME: 0
#     TSTEP: 10000
#     NTHIK: 1
#     NCOLS: 237
#     NROWS: 153
#     NLAYS: 1
#     NVARS: 191
#     GDTYP: 2
#     P_ALP: 33.0
#     P_BET: 45.0
#     P_GAM: -97.0
#     XCENT: -97.0
#     YCENT: 40.0
#     XORIG: 960000.0
#     YORIG: -660000.0
#     XCELL: 4000.0
#     YCELL: 4000.0
#     VGTYP: 7
#     VGTOP: 5000.0
#     VGLVLS: [1. 0.]
#     GDNAM: 4NC3
#     UPNAM: OPACONC
# ...

# %%
print (emis.variables)
# Out:
# {'TFLAG': <class 'netCDF4._netCDF4.Variable'>
# int32 TFLAG(TSTEP, VAR, DATE-TIME)
#     units: <YYYYDDD,HHMMSS>
#     long_name: TFLAG
#     var_desc: Timestep-valid flags:  (1) YYYYDDD or (2) HHMMSS
# unlimited dimensions: TSTEP
# current shape = (25, 67, 2)
# filling on, default _FillValue of -2147483647 used, 'ACET': <class 'netCDF4._netCDF4.Variable'>
# float32 ACET(TSTEP, LAY, ROW, COL)
#     long_name: ACET
#     units: moles/s
#     var_desc: Model species ACET
# unlimited dimensions: TSTEP
# current shape = (25, 1, 153, 237)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'ACROLEIN': <class 'netCDF4._netCDF4.Variable'>
# float32 ACROLEIN(TSTEP, LAY, ROW, COL)
#     long_name: ACROLEIN
#     units: moles/s
#     var_desc: Model species ACROLEIN
# unlimited dimensions: TSTEP
# current shape = (25, 1, 153, 237)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'ALD2': <class 'netCDF4._netCDF4.Variable'>
# float32 ALD2(TSTEP, LAY, ROW, COL)
# ...

# %%
print (met.variables)
# Out:
# {'TFLAG': <class 'netCDF4._netCDF4.Variable'>
# int32 TFLAG(TSTEP, VAR, DATE-TIME)
#     units: <YYYYDDD,HHMMSS>
#     long_name: TFLAG
#     var_desc: Timestep-valid flags:  (1) YYYYDDD or (2) HHMMSS
# unlimited dimensions: TSTEP
# current shape = (25, 41, 2)
# filling on, default _FillValue of -2147483647 used, 'PRSFC': <class 'netCDF4._netCDF4.Variable'>
# float32 PRSFC(TSTEP, LAY, ROW, COL)
#     long_name: PRSFC
#     units: Pa
#     var_desc: surface pressure
# unlimited dimensions: TSTEP
# current shape = (25, 1, 153, 237)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'USTAR': <class 'netCDF4._netCDF4.Variable'>
# float32 USTAR(TSTEP, LAY, ROW, COL)
#     long_name: USTAR
#     units: m s-1
#     var_desc: cell averaged friction velocity
# unlimited dimensions: TSTEP
# current shape = (25, 1, 153, 237)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'WSTAR': <class 'netCDF4._netCDF4.Variable'>
# float32 WSTAR(TSTEP, LAY, ROW, COL)
# ...

# %%
print (aq_conc.variables)
# Out:
# {'TFLAG': <class 'netCDF4._netCDF4.Variable'>
# int32 TFLAG(TSTEP, VAR, DATE-TIME)
#     units: <YYYYDDD,HHMMSS>
#     long_name: TFLAG
#     var_desc: Timestep-valid flags:  (1) YYYYDDD or (2) HHMMSS
# unlimited dimensions: TSTEP
# current shape = (24, 191, 2)
# filling on, default _FillValue of -2147483647 used, 'NO2': <class 'netCDF4._netCDF4.Variable'>
# float32 NO2(TSTEP, LAY, ROW, COL)
#     long_name: NO2
#     units: ppmV
#     var_desc: Variable NO2
# unlimited dimensions: TSTEP
# current shape = (24, 1, 153, 237)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'NO': <class 'netCDF4._netCDF4.Variable'>
# float32 NO(TSTEP, LAY, ROW, COL)
#     long_name: NO
#     units: ppmV
#     var_desc: Variable NO
# unlimited dimensions: TSTEP
# current shape = (24, 1, 153, 237)
# filling on, default _FillValue of 9.969209968386869e+36 used, 'O': <class 'netCDF4._netCDF4.Variable'>
# float32 O(TSTEP, LAY, ROW, COL)
#     long_name: O
#     units: ppmV
# ...
